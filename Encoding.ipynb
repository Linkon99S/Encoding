# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull()
# Out:
#     Marketing Spend  Administration  Transport   Area  Profit
# 0             False           False      False  False   False
# 1             False           False      False  False   False
# 2             False           False      False  False   False
# 3             False           False      False  False   False
# 4             False           False      False  False   False
# 5             False           False      False  False   False
# 6             False           False      False  False   False
# 7             False           False      False  False   False
# 8             False           False      False  False   False
# 9             False           False      False  False   False
# 10            False           False      False  False   False
# 11            False           False      False  False   False
# 12            False           False      False  False   False
# 13            False           False      False  False   False
# 14            False           False      False  False   False
# 15            False           False      False  False   False
# 16            False           False      False  False   False
# 17            False           False      False  False   False
# 18            False           False      False  False   False
# 19            False           False       True  False   False
# 20            False           False      False  False   False
# 21            False           False      False  False   False
# 22            False           False      False  False   False
# 23            False           False      False  False   False
# 24            False           False      False  False   False
# 25            False           False      False  False   False
# 26            False           False      False  False   False
# 27            False           False      False  False   False
# 28            False           False      False  False   False
# 29            False           False      False  False   False
# 30            False           False      False  False   False
# 31            False           False      False  False   False
# 32            False           False      False  False   False
# 33            False           False      False  False   False
# 34            False           False      False  False   False
# 35            False           False      False  False   False
# 36            False           False      False  False   False
# 37            False           False      False  False   False
# 38            False           False      False  False   False
# 39            False           False      False  False   False
# 40            False           False      False  False   False
# 41            False           False      False  False   False
# 42            False           False      False  False   False
# 43            False           False      False  False   False
# 44            False           False      False  False   False
# 45            False           False      False  False   False
# 46            False           False      False  False   False
# 47            False           False      False  False   False
# 48            False           False      False  False   False
# 49            False           False      False  False   False

# %%
df.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.isnull().sum().plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Creating multiple dataframes by copying from df

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()

# %%
from sklearn.preprocessing import RobustScaler
Ro=RobustScaler()

# %%
df['Marketing Spend'] = Ro.fit_transform(df[['Marketing Spend']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
ad = scaler.fit(df[['Administration']])

# %%
ad
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration'] = scaler.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.651744  471784.10    Dhaka  192261.83
# 1         1.452113        0.761972  443898.53      Ctg  191792.06
# 2         1.303634        0.379579  407934.54  Rangpur  191050.39
# 3         1.156567        0.512998  383199.62    Dhaka  182901.99
# 4         1.119836        0.305328  366168.42  Rangpur  166187.94

# %% [markdown]
# # Max()

# %%
df.Transport = df.Transport/ df.Transport.max()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.651744   1.000000    Dhaka  192261.83
# 1         1.452113        0.761972   0.940893      Ctg  191792.06
# 2         1.303634        0.379579   0.864664  Rangpur  191050.39
# 3         1.156567        0.512998   0.812235    Dhaka  182901.99
# 4         1.119836        0.305328   0.776136  Rangpur  166187.94

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.651744   1.000000    Dhaka  192261.83
# 1         1.452113        0.761972   0.940893      Ctg  191792.06
# 2         1.303634        0.379579   0.864664  Rangpur  191050.39
# 3         1.156567        0.512998   0.812235    Dhaka  182901.99
# 4         1.119836        0.305328   0.776136  Rangpur  166187.94

# %%
df1['Administration'] = scaler.transform(df1[['Administration']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       -0.000002   1.000000    Dhaka  192261.83
# 1         0.983359       -0.000002   0.940893      Ctg  191792.06
# 2         0.927985       -0.000002   0.864664  Rangpur  191050.39
# 3         0.873136       -0.000002   0.812235    Dhaka  182901.99
# 4         0.859438       -0.000002   0.776136  Rangpur  166187.94

# %%
df1.Transport = df.Transport/ df.Transport.max()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       -0.390389   1.000000    Dhaka  192261.83
# 1         0.983359       -0.390388   0.940893      Ctg  191792.06
# 2         0.927985       -0.390391   0.864664  Rangpur  191050.39
# 3         0.873136       -0.390390   0.812235    Dhaka  182901.99
# 4         0.859438       -0.390392   0.776136  Rangpur  166187.94

# %% [markdown]
# # Fit and transform for 'Marketing Spend'

# %%
df2['Marketing Spend'] = scaler.fit_transform(df2[['Marketing Spend']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Fit and transform for 'Administration'

# %%
df3['Transport'] = scaler.fit_transform(df3[['Transport']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.000000    Dhaka  192261.83
# 1        162597.70       151377.59   0.940893      Ctg  191792.06
# 2        153441.51       101145.55   0.864664  Rangpur  191050.39
# 3        144372.41       118671.85   0.812235    Dhaka  182901.99
# 4        142107.34        91391.77   0.776136  Rangpur  166187.94

# %% [markdown]
# # Importing MaxAbsScaler from sklearn.preprocessing

# %%
from sklearn.preprocessing import MaxAbsScaler
max_scaler = MaxAbsScaler()

# %%
df3.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df3['Marketing Spend'] = max_scaler.fit_transform(df3[['Marketing Spend']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80   1.000000    Dhaka  192261.83
# 1         0.983359       151377.59   0.940893      Ctg  191792.06
# 2         0.927985       101145.55   0.864664  Rangpur  191050.39
# 3         0.873136       118671.85   0.812235    Dhaka  182901.99
# 4         0.859438        91391.77   0.776136  Rangpur  166187.94

# %%
df3['Administration'] = max_scaler.fit_transform(df3[['Administration']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94

# %%
df3.Transport = df.Transport/ df.Transport.max()

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.749527   1.000000    Dhaka  192261.83
# 1         0.983359        0.828805   0.940893      Ctg  191792.06
# 2         0.927985        0.553781   0.864664  Rangpur  191050.39
# 3         0.873136        0.649738   0.812235    Dhaka  182901.99
# 4         0.859438        0.500378   0.776136  Rangpur  166187.94

# %% [markdown]
# # importing RobustScaler from sklearn.preprocessing

# %%
from sklearn.preprocessing import RobustScaler
robust_scaler=RobustScaler()

# %%
df4.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df4['Marketing Spend'] = robust_scaler.fit_transform(df4[['Marketing Spend']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94

# %%
df4['Administration'] = robust_scaler.fit_transform(df4[['Administration']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355  471784.10    Dhaka  192261.83
# 1         1.452113        0.697565  443898.53      Ctg  191792.06
# 2         1.303634       -0.524290  407934.54  Rangpur  191050.39
# 3         1.156567       -0.097977  383199.62    Dhaka  182901.99
# 4         1.119836       -0.761543  366168.42  Rangpur  166187.94

# %%
df4['Transport'] = robust_scaler.fit_transform(df4[['Transport']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.672530        0.345355   1.552016    Dhaka  192261.83
# 1         1.452113        0.697565   1.383714      Ctg  191792.06
# 2         1.303634       -0.524290   1.166654  Rangpur  191050.39
# 3         1.156567       -0.097977   1.017368    Dhaka  182901.99
# 4         1.119836       -0.761543   0.914576  Rangpur  166187.94
